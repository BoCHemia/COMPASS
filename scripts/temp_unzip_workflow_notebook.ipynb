# %%
import os 
from zipfile import ZipFile 
import pickle

# %%
os.path.join("..", "temp","data_market_trained_tSNE.zip")

# %%
zip_path = "C:\\Users\\corderjo\\Downloads\\my_compression\\\data_market_trained_tSNE.pkl"

archive = ZipFile(zip_path, mode='r')

# %%
import zipfile
import pickle

def unzip_and_load_pkl():
    with zipfile.ZipFile(os.path.join("..", "temp","data_market_trained_tSNE.zip")) as z:
        # List files
        print(z.namelist())

        # Grab the first (and only) entry
        info = z.infolist()[1]

        # with z.read(info) as f:
        #     print(type(f))
        
        #     # obj = pickle.load(f)  

        f = z.open(info)
        print(type(f))
        
        $
    return obj
pkl = unzip_and_load_pkl()

# %%
pkl

# %%
with zipfile.ZipFile(os.path.join("..", "output","trained_tSNE_small.zip"), mode="r") as archive:
    archive.printdir()
    archive.extractall(path=os.path.join("..","output","python_extracted_pickle"))

# %%
extraction_folder = os.path.join("..","output","python_extracted_pickle")
with
